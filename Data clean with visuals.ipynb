# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("NGX Stocks 2000 - 2025.csv")
data.head()
# Out:
#      Symbol              Sector        Date  index  Price  Open  High   Low  \
# 0  ABBEYBDS  FINANCIAL SERVICES  2025-05-16      0   6.87  7.63  7.54  6.87
# 1  ABBEYBDS  FINANCIAL SERVICES  2025-05-15      1   7.63  7.63  7.63  7.63
# 2  ABBEYBDS  FINANCIAL SERVICES  2025-05-14      2   7.63  7.63  7.63  7.63
# 3  ABBEYBDS  FINANCIAL SERVICES  2025-05-13      3   7.63  7.63  7.63  7.63
# 4  ABBEYBDS  FINANCIAL SERVICES  2025-05-12      4   7.69  7.00  7.69  7.69
#
#   Change %  vol multiplier     Volume             Company Name  \
# 0   -9.96%          1000.0    40500.0  ABBEY MORTGAGE BANK PLC
# 1    0.00%          1000.0    33610.0  ABBEY MORTGAGE BANK PLC
# 2    0.00%          1000.0    33680.0  ABBEY MORTGAGE BANK PLC
# 3   -0.78%          1000.0   223780.0  ABBEY MORTGAGE BANK PLC
# 4    9.86%       1000000.0  1830000.0  ABBEY MORTGAGE BANK PLC
#
#                        SubSector Market Classification  Shares Outstanding  \
# 0  Mortgage Carriers, Brokers an            Main Board        1.015385e+10
# 1  Mortgage Carriers, Brokers an            Main Board        1.015385e+10
# 2  Mortgage Carriers, Brokers an            Main Board        1.015385e+10
# 3  Mortgage Carriers, Brokers an            Main Board        1.015385e+10
# 4  Mortgage Carriers, Brokers an            Main Board        1.015385e+10
#
#      Market Cap
# 0  6.975692e+10
# 1  7.747385e+10
# 2  7.747385e+10
# 3  7.747385e+10
# 4  7.808308e+10

# %%
data.tail()
# Out:
#             Symbol              Sector        Date  index  Price   Open  \
# 307577  ZENITHBANK  FINANCIAL SERVICES  2012-01-27   3289  12.10  12.01
# 307578  ZENITHBANK  FINANCIAL SERVICES  2012-01-26   3290  12.02  12.00
# 307579  ZENITHBANK  FINANCIAL SERVICES  2012-01-25   3291  12.00  12.00
# 307580  ZENITHBANK  FINANCIAL SERVICES  2012-01-24   3292  11.96  12.00
# 307581  ZENITHBANK  FINANCIAL SERVICES  2012-01-23   3293  12.00  12.05
#
#          High    Low Change %  vol multiplier       Volume     Company Name  \
# 307577  12.22  12.01    0.67%       1000000.0  117010000.0  ZENITH BANK PLC
# 307578  12.02  11.97    0.17%       1000000.0   61360000.0  ZENITH BANK PLC
# 307579  12.10  11.95    0.33%       1000000.0   46580000.0  ZENITH BANK PLC
# 307580  12.00  11.95   -0.33%       1000000.0    8270000.0  ZENITH BANK PLC
# 307581  12.05  11.95   -0.83%       1000000.0   16150000.0  ZENITH BANK PLC
#
#        SubSector Market Classification  Shares Outstanding    Market Cap
# 307577   Banking         Premium Board        4.106983e+10  4.969449e+11
# 307578   Banking         Premium Board        4.106983e+10  4.936594e+11
# 307579   Banking         Premium Board        4.106983e+10  4.928380e+11
# 307580   Banking         Premium Board        4.106983e+10  4.911952e+11
# 307581   Banking         Premium Board        4.106983e+10  4.928380e+11

# %%
data.shape
# Out:
# (307582, 16)

# %%
data.info
# Out:
# <bound method DataFrame.info of             Symbol              Sector        Date  index  Price   Open  \
# 0         ABBEYBDS  FINANCIAL SERVICES  2025-05-16      0   6.87   7.63
# 1         ABBEYBDS  FINANCIAL SERVICES  2025-05-15      1   7.63   7.63
# 2         ABBEYBDS  FINANCIAL SERVICES  2025-05-14      2   7.63   7.63
# 3         ABBEYBDS  FINANCIAL SERVICES  2025-05-13      3   7.63   7.63
# 4         ABBEYBDS  FINANCIAL SERVICES  2025-05-12      4   7.69   7.00
# ...            ...                 ...         ...    ...    ...    ...
# 307577  ZENITHBANK  FINANCIAL SERVICES  2012-01-27   3289  12.10  12.01
# 307578  ZENITHBANK  FINANCIAL SERVICES  2012-01-26   3290  12.02  12.00
# 307579  ZENITHBANK  FINANCIAL SERVICES  2012-01-25   3291  12.00  12.00
# 307580  ZENITHBANK  FINANCIAL SERVICES  2012-01-24   3292  11.96  12.00
# 307581  ZENITHBANK  FINANCIAL SERVICES  2012-01-23   3293  12.00  12.05
#
#          High    Low Change %  vol multiplier       Volume  \
# 0        7.54   6.87   -9.96%          1000.0      40500.0
# 1        7.63   7.63    0.00%          1000.0      33610.0
# 2        7.63   7.63    0.00%          1000.0      33680.0
# 3        7.63   7.63   -0.78%          1000.0     223780.0
# 4        7.69   7.69    9.86%       1000000.0    1830000.0
# ...       ...    ...      ...             ...          ...
# 307577  12.22  12.01    0.67%       1000000.0  117010000.0
# 307578  12.02  11.97    0.17%       1000000.0   61360000.0
# 307579  12.10  11.95    0.33%       1000000.0   46580000.0
# 307580  12.00  11.95   -0.33%       1000000.0    8270000.0
# 307581  12.05  11.95   -0.83%       1000000.0   16150000.0
#
#                    Company Name                      SubSector  \
# 0       ABBEY MORTGAGE BANK PLC  Mortgage Carriers, Brokers an
# 1       ABBEY MORTGAGE BANK PLC  Mortgage Carriers, Brokers an
# 2       ABBEY MORTGAGE BANK PLC  Mortgage Carriers, Brokers an
# 3       ABBEY MORTGAGE BANK PLC  Mortgage Carriers, Brokers an
# 4       ABBEY MORTGAGE BANK PLC  Mortgage Carriers, Brokers an
# ...                         ...                            ...
# 307577          ZENITH BANK PLC                        Banking
# 307578          ZENITH BANK PLC                        Banking
# 307579          ZENITH BANK PLC                        Banking
# 307580          ZENITH BANK PLC                        Banking
# 307581          ZENITH BANK PLC                        Banking
#
#        Market Classification  Shares Outstanding    Market Cap
# 0                 Main Board        1.015385e+10  6.975692e+10
# 1                 Main Board        1.015385e+10  7.747385e+10
# 2                 Main Board        1.015385e+10  7.747385e+10
# 3                 Main Board        1.015385e+10  7.747385e+10
# 4                 Main Board        1.015385e+10  7.808308e+10
# ...                      ...                 ...           ...
# 307577         Premium Board        4.106983e+10  4.969449e+11
# 307578         Premium Board        4.106983e+10  4.936594e+11
# 307579         Premium Board        4.106983e+10  4.928380e+11
# 307580         Premium Board        4.106983e+10  4.911952e+11
# 307581         Premium Board        4.106983e+10  4.928380e+11
#
# [307582 rows x 16 columns]>

# %%
data.describe()
# Out:
#                index          Price           Open           High  \
# count  307582.000000  307582.000000  307582.000000  307582.000000
# mean     1399.121174      48.676873      48.715324      47.009568
# std      1006.340144     228.053227     227.770200     225.550442
# min         0.000000       0.130000       0.000000       0.000000
# 25%       550.000000       1.000000       1.020000       0.819000
# 50%      1230.000000       3.560000       3.600000       3.240000
# 75%      2116.000000      17.900000      18.150000      16.420000
# max      4999.000000    5738.200000    5738.200000    5738.200000
#
#                  Low  vol multiplier        Volume  Shares Outstanding  \
# count  307582.000000    2.905050e+05  2.905050e+05        3.075820e+05
# mean       45.992708    4.577776e+05  4.065639e+06        1.144641e+10
# std       221.681140    1.082444e+07  3.030792e+07        1.989358e+10
# min         0.000000    1.000000e+03  0.000000e+00        1.000000e+07
# 25%         0.790000    1.000000e+03  4.779000e+04        1.000000e+09
# 50%         3.090000    1.000000e+03  3.429400e+05        4.273105e+09
# 75%        16.000000    1.000000e+06  1.880000e+06        1.422814e+10
# max      5700.000000    1.000000e+09  6.670000e+09        1.682916e+11
#
#          Market Cap
# count  3.075820e+05
# mean   2.625854e+11
# std    8.685569e+11
# min    9.000000e+06
# 25%    3.661915e+09
# 50%    1.332273e+10
# 75%    7.458847e+10
# max    1.287453e+13

# %%
data.isnull().sum()
# Out:
# Symbol                       0
# Sector                       0
# Date                         0
# index                        0
# Price                        0
# Open                         0
# High                         0
# Low                          0
# Change %                     0
# vol multiplier           17077
# Volume                   17077
# Company Name                 0
# SubSector                    0
# Market Classification        0
# Shares Outstanding           0
# Market Cap                   0
# dtype: int64

# %%
data=data.dropna

# %%
data.columns = data.columns.str.strip().str.lower()

# %%
data.hist()
plt.title("Histogram")
plt.show()

# %%
plt.scatter(data['high'], data['low'])
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Scatter Plot")
plt.show()

# %%
data.columns = data.columns.str.strip()     
data.columns = data.columns.str.lower()      
data.columns = data.columns.str.replace(" ", "_")

# %%
data['vol_multiplier'].value_counts().plot(kind='bar')
plt.title("Bar Chart")
plt.show()

# %%
plt.boxplot(data['open'])
plt.title("Box Plot")
plt.show()

# %%
corr = data.corr(numeric_only=True)

sns.heatmap(corr, annot=True)
plt.title("Correlation Heatmap")
plt.show()
